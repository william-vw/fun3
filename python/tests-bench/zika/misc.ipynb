# %%
import os, sys
sys.path.insert(0, "../..")
from n3.parse import parse_n3_file

# %%
# get the number of triples of the datasets

folder = os.path.join("data")
files = os.listdir(folder)
files.sort()
for file in files:
    if not file.endswith(".n3"):
        continue
    data = parse_n3_file(os.path.join(folder, file)).data
    print(file, len(data))
# Out:
# gen1000_pt1.n3 9435
# gen1000_pt2.n3 16878
# gen100_pt1.n3 875
# gen100_pt2.n3 1749
# gen2000_pt1.n3 18252
# gen2000_pt2.n3 34945
# gen200_pt1.n3 1882
# gen200_pt2.n3 3312
# gen5000_pt1.n3 44916
# gen5000_pt2.n3 83582
# gen500_pt1.n3 4603
# gen500_pt2.n3 7734
# gen700_pt1.n3 6353
# gen700_pt2.n3 11873
