# %%
from parse import parse_n3_file as cpp_parse

path = "/Users/wvw/git/n3/fun3/python/tests-bench/zika/data/gen20000_pt2.n3"
result = cpp_parse(path, measure_time=True)

print("# triples:", len(result.data))
# Out:
# time: 8.284664154052734
# # triples: 335738
